# %%
# %%capture
# Install deps in current jupyter kernel python
import sys
# !{sys.executable} -m pip install google-cloud-storage
# !{sys.executable} -m pip install google-cloud-bigquery

# %%
# Pull in script deps
import requests
import json
import csv
import datetime
from google.cloud import storage
from google.cloud import bigquery
from google.cloud.bigquery import LoadJobConfig
from google.cloud.bigquery import SchemaField

# %%
# globals, constants, etc.
TZ = 'EST04EDT'
BUCKET = 'bsc-caserta-datatest'
NOW = datetime.datetime.now()
YEAR = NOW.year
MONTH = NOW.month
DAY = NOW.day
HOUR = NOW.hour
MIN = NOW.minute
SEC = NOW.second
BQ = {
  'dataset_name': 'coinmarketcap',
  'table_name': '{}{}{}'.format(YEAR, MONTH, DAY)
}
FILENAME = '{}/{}/{}'.format(YEAR, MONTH, DAY)

def upload_blob(bucket_name, source_file_name, destination_blob_name):
  """Uploads a file to the bucket."""
  storage_client = storage.Client()
  bucket = storage_client.get_bucket(bucket_name)
  blob = bucket.blob(destination_blob_name)

  blob.upload_from_filename(source_file_name)

def get_blob(bucket_name, source_file_name):
  client = storage.Client()
  bucket = client.get_bucket(bucket_name)
  blob = bucket.get_blob(source_file_name)
  return blob.download_as_string()

# %%
# Get the data from the API, run through the JSON output,
# package it into python lists, and dump a CSV file locally
r = requests.get('https://api.coinmarketcap.com/v2/ticker/?start=0&limit=1') #grab metadata
num_cryptocurrencies = r.json()[u'metadata']['num_cryptocurrencies']

csv_data = [['id', 'name', 'symbol', 'usd_price',
            'usd_market_cap', 'usd_pct_chg_1h', 'usd_pct_chg_24h',
            'usd_pct_chg_7d', 'usd_volume_24h', 'total_supply',
            'max_supply', 'circulating_supply']]

for i in range(0, num_cryptocurrencies, 100):
  r = requests.get('https://api.coinmarketcap.com/v2/ticker/?start={}&limit=100'.format(i))
  data = r.json()[u'data']

  for d in set(data):
    x = data[d]
    x_quote = x['quotes']['USD']

    csv_data.append([x['id'], x['name'], x['symbol'], x_quote['price'],
          x_quote['market_cap'], x_quote['percent_change_1h'], x_quote['percent_change_24h'],
          x_quote['percent_change_7d'], x_quote['volume_24h'], x['total_supply'],
          x['max_supply'], x['circulating_supply']])

# quick sanity check of data
if len(csv_data)-1 != num_cryptocurrencies:
  print(len(csv_data)-1)
  print(num_cryptocurrencies)
  
print(csv_data[0:5])
  
# write everything to a local CSV file
with open('{}.csv'.format(DAY), 'w', newline='') as csvfile:
    csvwriter = csv.writer(csvfile, dialect='excel')
    for i in csv_data:
      csvwriter.writerow(i)
# Out:
# 2091
# 2090
# [['id', 'name', 'symbol', 'usd_price', 'usd_market_cap', 'usd_pct_chg_1h', 'usd_pct_chg_24h', 'usd_pct_chg_7d', 'usd_volume_24h', 'total_supply', 'max_supply', 'circulating_supply'], [131, 'Dash', 'DASH', 163.584386234, 1371752838.0, -0.13, -0.63, -8.55, 170713367.683366, 8385598.0, 18900000.0, 8385598.0], [1896, '0x', 'ZRX', 0.9905214863, 536426475.0, -2.34, 34.61, 33.05, 122315800.553535, 1000000000.0, None, 541559655.0], [1042, 'Siacoin', 'SC', 0.006690731, 250403123.0, 0.21, 3.08, -6.9, 3600825.45931643, 37425376014.0, None, 37425376014.0], [2083, 'Bitcoin Gold', 'BTG', 26.7405630008, 462392430.0, 0.3, 0.98, 1.74, 2501787.85944407, 17391799.0, 21000000.0, 17291799.0]]

# %%
# Put the CSV file in the bucket
upload_blob(BUCKET, '{}.csv'.format(DAY), FILENAME)

# %%
# Load CSV in BigQuery
bq = bigquery.Client()

SCHEMA = [
  SchemaField('id', 'INTEGER', mode='required'),
  SchemaField('name', 'STRING', mode='required'),
  SchemaField('symbol', 'STRING', mode='required'),
  SchemaField('usd_price', 'FLOAT', mode='required'),
  SchemaField('usd_market_cap', 'FLOAT'),
  SchemaField('usd_pct_chg_1h', 'FLOAT'),
  SchemaField('usd_pct_chg_24h', 'FLOAT'),
  SchemaField('usd_pct_chg_7d', 'FLOAT'),
  SchemaField('usd_volume_24h', 'FLOAT'),
  SchemaField('total_supply', 'FLOAT'),
  SchemaField('max_supply', 'FLOAT'),
  SchemaField('circulating_supply', 'FLOAT'),
]

dataset_ref = bq.dataset(BQ['dataset_name'])

load_config = bigquery.LoadJobConfig()
load_config.skip_leading_rows = 1
load_config.schema = SCHEMA

uri = 'gs://{}/{}/{}/{}'.format(BUCKET, YEAR, MONTH, DAY)
bq.delete_table(dataset_ref.table(BQ['table_name'])) 
load_job = bq.load_table_from_uri(
    uri,
    dataset_ref.table(BQ['table_name']),
    job_config=load_config)

print('Starting job {}'.format(load_job.job_id))

load_job.result()  # Waits for table load to complete.
print('Job finished.')

destination_table = bq.get_table(dataset_ref.table(BQ['table_name']))
print('Loaded {} rows.'.format(destination_table.num_rows))
# Out:
# Starting job 74b8ae84-4b16-41ab-820b-aaea203f9baf
# Job finished.
# Loaded 2091 rows.

# %%
#Run some queries
# 1 -- price > $8000

q = ('SELECT name, symbol, usd_price FROM `coinmarketcap.20181017` WHERE usd_price > 8000;')
query_job = bq.query(q)  # API request
rows = query_job.result()  # Waits for query to finish

i = 0
for row in rows:
  i += 1
  print(row)
  
print('\n{} coins have a price > $8000'.format(i))
# Out:
# Row(('Bit20', 'BTWTY', 215104.182628), {'name': 0, 'symbol': 1, 'usd_price': 2})
# Row(('Project-X', 'NANOX', 47656.0145424), {'name': 0, 'symbol': 1, 'usd_price': 2})
# Row(('42-coin', '42', 22073.4112929), {'name': 0, 'symbol': 1, 'usd_price': 2})
#
# 3 coins have a price > $8000

# %%
# 2 -- sum of top 100 market cap

q = ('SELECT name, symbol, usd_market_cap FROM `coinmarketcap.20181017` ORDER BY usd_market_cap DESC LIMIT 100;')
query_job = bq.query(q)  # API request
rows = query_job.result()  # Waits for query to finish

total = 0
for row in rows:
  total += row[2]
  
print('Total market cap of top 100 coins is ${}'.format(total))
# Out:
# Total market cap of top 100 coins is $204192023116.0

# %%
# 3 -- supply < $5M

q = ('SELECT name, symbol, ((COALESCE(total_supply, max_supply) - circulating_supply) * usd_price) AS usd_avail_supply FROM `coinmarketcap.20181017` WHERE COALESCE(total_supply, max_supply) IS NOT NULL AND (COALESCE(total_supply, max_supply) * usd_price) < 5000000 ORDER BY usd_avail_supply DESC;')
query_job = bq.query(q)  # API request
rows = query_job.result()  # Waits for query to finish

for row in rows:
  print(row)
# Out:
# Row(('KUN', 'KUN', 4381628.2564508), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('NEVERDIE', 'NDC', 4155834.0687454203), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Traceability Chain', 'TAC', 3870131.7095113457), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Sharpay', 'S', 3683062.2059170282), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Kryll', 'KRL', 3345861.327841599), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Bethereum', 'BETHER', 3316780.3479705425), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('GoldMint', 'MNTP', 3265332.750980303), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Simmitri', 'SIM', 3194086.8583279857), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('SkinCoin', 'SKIN', 3191072.04), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('BlockMesh', 'BMH', 3143719.6861048345), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('MTC Mesh Network', 'MTC', 3088311.375849707), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Bigbom', 'BBO', 3079576.978953096), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Starbase', 'STAR', 2992730.1625), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Bounty0x', 'BNTY', 2953095.6056654975), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('HelloGold', 'HGT', 2943544.388396201), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('eBoost', 'EBST', 2890826.64294272), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('CryptoFlow', 'CFL', 2878570.344416974), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Pal Network', 'PAL', 2858001.4908931246), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('AidCoin', 'AID', 2820012.201813094), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('ShipChain', 'SHIP', 2800085.3886419786), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('ShowHand', 'HAND', 2788152.087336943), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Bee Token', 'BEE', 2787351.311331502), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('BitClave', 'CAT', 2775267.0269774664), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('UChain', 'UCN', 2737868.897472891), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Proton Token', 'PTT', 2725875.504807844), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Jetcoin', 'JET', 2644368.2801009393), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Alphacat', 'ACAT', 2601731.274350766), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Debitum', 'DEB', 2552408.388064231), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('FundYourselfNow', 'FYN', 2544783.0407176903), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('CanYaCoin', 'CAN', 2539865.359153312), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('JET8', 'J8T', 2515765.3133575143), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('LatiumX', 'LATX', 2507870.795854263), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Qwark', 'QWARK', 2441091.1929472224), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('PikcioChain', 'PKC', 2412172.4324804875), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('BitScreener Token', 'BITX', 2348694.7087499998), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Naviaddress', 'NAVI', 2345471.985148277), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('On.Live', 'ONL', 2276989.740402655), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('SoMee.Social', 'ONG', 2264293.7390471455), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Mithril Ore', 'MORE', 2264074.645111053), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('RealChain', 'RCT', 2164972.762205577), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('MetaMorph', 'METM', 2147224.640365681), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Kora Network Token', 'KNT', 2132129.0100000002), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('0xcert', 'ZXC', 2116927.3895), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('HeroNode', 'HER', 2093322.7730916773), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Travala', 'AVA', 2041883.9436245598), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Expanse', 'EXP', 2017676.7612), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Parkgene', 'GENE', 2016313.670532772), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Tidex Token', 'TDX', 2014384.406555621), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('IXT', 'IXT', 1986740.778), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('BelugaPay', 'BBI', 1984327.551271621), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Decentralized Machine Learning', 'DML', 1976229.268654682), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('AdCoin', 'ACC', 1955052.7635173688), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Lampix', 'PIX', 1946013.3924728571), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Energo', 'TSL', 1942039.1688250317), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Relex', 'RLX', 1925144.7339465073), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Lendingblock', 'LND', 1922461.3900624358), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('MyBit', 'MYB', 1917171.763311198), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('SyncFab', 'MFG', 1916583.5953807447), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Spectre.ai Utility Token', 'SXUT', 1902745.5329650994), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Mercury Protocol', 'GMT', 1889160.0976257126), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Patron', 'PAT', 1876664.1133560052), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Seal Network', 'SEAL', 1849763.28), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('CoinFi', 'COFI', 1809461.8987154008), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Aventus', 'AVT', 1803728.0932), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Smoke', 'SMOKE', 1788578.0675991706), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Hackspace Capital', 'HAC', 1784871.5904298548), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Auctus', 'AUC', 1764859.9443105487), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('CargoX', 'CXO', 1762695.1937078906), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('1World', '1WO', 1757853.8596778696), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('imbrex', 'REX', 1753787.6739517534), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Peculium', 'PCL', 1747608.228219361), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Faceter', 'FACE', 1720555.0325501696), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('EventChain', 'EVC', 1717671.7694860143), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('ALIS', 'ALIS', 1712654.3217873822), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Bitether', 'BTR', 1697945.2515866763), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Digital Insurance Token', 'DIT', 1664579.94598116), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Guaranteed Ethurance Token Extra', 'GETX', 1651618.71), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('STRAKS', 'STAK', 1649145.265941761), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Welltrado', 'WTL', 1638850.481143662), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('RusGas', 'RGS', 1616169.6272325849), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('HollyWoodCoin', 'HWC', 1606553.039990607), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('HEROcoin', 'PLAY', 1597983.8742436368), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Sharpe Platform Token', 'SHP', 1572360.6075317424), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Education Ecosystem', 'LEDU', 1539917.2792041213), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('REAL', 'REAL', 1530337.337366221), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Bezop', 'BEZ', 1515209.9146400944), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Pareto Network', 'PARETO', 1502255.3558279977), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Gatcoin', 'GAT', 1493369.249631195), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('REBL', 'REBL', 1477302.9296543146), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Omnitude', 'ECOM', 1468691.4126666002), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Nimiq', 'NIM', 1456066.8742121723), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('FLIP', 'FLP', 1455399.8343525), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Opus', 'OPT', 1437947.5961735917), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Repme', 'RPM', 1434158.0648565656), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Rapids', 'RPD', 1433725.6332934499), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Speed Mining Service', 'SMS', 1423717.900191528), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Webchain', 'WEB', 1405325.845), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('RED', 'RED', 1393914.5667823898), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Astro', 'ASTRO', 1391532.293718646), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Amon', 'AMN', 1384820.781909828), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Coinlancer', 'CL', 1358790.390429381), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('BunnyToken', 'BUNNY', 1335172.2714676312), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('StarCredits', 'STRC', 1314305.80805), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Kubera Coin', 'KBR', 1302585.316976598), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('LOCIcoin', 'LOCI', 1270721.400998934), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('EnergiToken', 'ETK', 1253791.190351241), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('adbank', 'ADB', 1227109.349107607), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('X-Cash', 'XCASH', 1226924.4), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Dragonglass', 'DGS', 1225339.0207539464), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('CrevaCoin', 'CREVA', 1224479.76746847), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Joint Ventures', 'JOINT', 1218327.8467001314), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('PHI Token', 'PHI', 1203505.3204713778), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('IP Exchange', 'IPSX', 1177570.0839705176), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Xenon', 'XNN', 1154232.45), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('EZToken', 'EZT', 1127904.2968465), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('ZINC', 'ZINC', 1104937.7386681943), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Sumokoin', 'SUMO', 1104910.4644780473), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Mysterium', 'MYST', 1095969.69889872), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('VouchForMe', 'IPL', 1088394.1497), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Daneel', 'DAN', 1084094.137708714), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Master Swiscoin', 'MSCN', 1076486.634676908), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('VeriME', 'VME', 1067381.7982334353), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('AirToken', 'AIR', 1063083.4842297307), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Engagement Token', 'ENGT', 1061833.1043596792), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('ATMChain', 'ATM', 1057609.492422192), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Forkcoin', 'FORK', 1050965.71591508), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Matchpool', 'GUP', 1050679.92891928), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('COPYTRACK', 'CPY', 1048254.16744566), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('bitJob', 'STU', 1041444.335678319), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('FarmaTrust', 'FTT', 1032915.1599999999), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('EchoLink', 'EKO', 1031510.1182470398), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Energi', 'NRG', 1014092.4318416801), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Veros', 'VRS', 1004957.24916272), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('TrueFlip', 'TFL', 1003843.40480952), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Patientory', 'PTOY', 999785.2859091999), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Bridge Protocol', 'TOLL', 994821.744), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Aditus', 'ADI', 984580.302976788), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Snovian.Space', 'SNOV', 981950.5324534825), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('LikeCoin', 'LIKE', 980169.8369830741), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Proxeus', 'XES', 977534.4901322001), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Sapien', 'SPN', 975672.1834561108), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Paypex', 'PAYX', 963888.4451089377), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Helbiz', 'HBZ', 958693.7427931386), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('FoldingCoin', 'FLDC', 947071.1606419364), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Aphelion', 'APH', 939412.92144258), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Publica', 'PBL', 908568.4589402323), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Ultimate Secure Cash', 'USC', 904828.1521119113), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('BlitzPredict', 'XBP', 904519.962276988), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Sugar Exchange', 'SGR', 898430.6353347752), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Leadcoin', 'LDC', 897285.4943545007), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Peerplays', 'PPY', 892187.4247640384), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Verify', 'CRED', 891510.5738567068), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Nitro', 'NOX', 882848.5475052455), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Musiconomi', 'MCI', 880545.570507088), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Insights Network', 'INSTAR', 864021.069541622), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('TRONCLASSIC', 'TRXC', 860321.131789692), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Auxilium', 'AUX', 835361.4208230863), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Commodity Ad Network', 'CDX', 831089.2515749999), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Profile Utility Token', 'PUT', 830713.3408045188), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Orbis Token', 'OBT', 823347.5405735169), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('FlypMe', 'FYP', 812724.4485010103), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('ClearCoin', 'XCLR', 804891.0106963405), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Devery', 'EVE', 801987.453431073), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('BitDegree', 'BDG', 792845.1149211295), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Thrive Token', 'THRT', 784723.5418475879), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Ether Kingdoms Token', 'IMP', 754023.758312064), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('CyberFM', 'CYFM', 748737.12), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Motocoin', 'MOTO', 741948.767147056), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Neurotoken', 'NTK', 735169.124055593), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('GoByte', 'GBX', 728831.8341361864), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('FUTURAX', 'FTXT', 713463.7001032593), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Yocoin', 'YOC', 711263.097479), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Playkey', 'PKT', 698778.0296301288), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Hedge', 'HDG', 695902.2073568769), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('PoSW Coin', 'POSW', 693862.35716), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Sola Token', 'SOL', 689519.2005479999), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Maverick Chain', 'MVC', 688314.4194326643), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Knekted', 'KNT', 686574.72), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('VikkyToken', 'VIKKY', 677916.7757978742), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Gold Poker', 'GPKR', 671076.7975002024), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('DeviantCoin', 'DEV', 670046.548489899), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Ccore', 'CCO', 667829.9096214252), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('CryptoCarbon', 'CCRB', 660374.3938709736), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Circuits of Value', 'COVAL', 657897.9), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('HOQU', 'HQX', 656842.031892852), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('GeoCoin', 'GEO', 655072.8603782409), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Freicoin', 'FRC', 652690.4204887872), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Bonpay', 'BON', 626848.9197330546), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Envion', 'EVN', 619127.21975076), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('FirstCoin', 'FRST', 612065.9422408608), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('IQ.cash', 'IQ', 608588.27512), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Experience Points', 'XP', 605178.5605755808), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('HireMatch', 'HIRE', 589545.411553884), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('IGToken', 'IG', 585218.9736748575), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('ATLANT', 'ATL', 583597.575747996), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Signals Network', 'SGN', 580607.55281475), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Webcoin', 'WEB', 578589.1407745284), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Kind Ads Token', 'KIND', 577147.3880656512), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('TrakInvest', 'TRAK', 576515.64035455), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('MCAP', 'MCAP', 560359.72153), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('CVCoin', 'CVN', 556009.177288448), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Target Coin', 'TGT', 549911.039153066), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('APX', 'APX', 543811.7339), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Global Cryptocurrency', 'GCC', 539433.0309136136), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Jury.Online Token', 'JOT', 530636.754897345), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('IQeon', 'IQN', 528498.7545618206), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Sharder', 'SS', 525738.123250431), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Etheera', 'ETA', 520580.42219082115), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('SounDAC', 'XSD', 518850.4839), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('BrokerNekoNetwork', 'BNN', 516673.1442593336), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('SGPay', 'SGP', 515670.42919), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('CFun', 'CFUN', 511078.45706388156), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('ThoreCoin', 'THR', 504054.17761646194), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Zilla', 'ZLA', 494386.99681204255), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Project Coin', 'PRJ', 494047.29438), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Bitzeny', 'ZNY', 492639.82217104995), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Swisscoin', 'SIC', 491277.84507456725), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Bitcoin 21', 'XBTC21', 482035.21379999997), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Banca', 'BANCA', 481899.2057236224), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Thore Cash', 'TCH', 481700.93790998), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('HeartBout', 'HB', 475706.75985000003), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('LoMoCoin', 'LMC', 475426.77699999994), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Sharechain', 'SSS', 475088.85391192883), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('ClearPoll', 'POLL', 474323.8417618023), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('PeepCoin', 'PCN', 473061.68), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Soma', 'SCT', 471262.84314537514), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('AB-Chain RTB', 'RTB', 469166.96535951056), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Monster Byte', 'MBI', 465634.130918), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Cryptopay', 'CPAY', 464889.2254677936), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Zenswap Network Token', 'ZNT', 451622.32603580796), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('FundRequest', 'FND', 442213.40069576557), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('BitStation', 'BSTN', 441782.7160815018), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('MNPCoin', 'MNP', 434704.6707804846), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Goodomy', 'GOOD', 423275.8910980491), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('EagleX', 'EGX', 420795.02902545), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('AC3', 'AC3', 417827.1938492116), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('EvenCoin', 'EVN', 414509.05903565884), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('ShareX', 'SEXC', 410361.4975154375), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('BitRewards', 'BIT', 403597.564447059), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('EncrypGen', 'DNA', 401800.6564981942), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('ZoZoCoin', 'ZZC', 398352.01774543995), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Fidelium', 'FID', 397357.39210989), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Elysian', 'ELY', 394534.1176622528), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Wild Crypto', 'WILD', 388282.67191005603), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('DeusCoin', 'DEUS', 388026.1848102657), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Fujinto', 'NTO', 387396.288018792), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Travelflex', 'TRF', 373388.5623015408), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Hurify', 'HUR', 371576.822762357), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Spectiv', 'SIG', 370636.2115971665), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('CoinPoker', 'CHP', 366343.9837673835), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('DNotes', 'NOTE', 363220.056), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Dorado', 'DOR', 359464.599), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Earth Token', 'EARTH', 359316.637085), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('DigiPulse', 'DGPT', 358367.61987592385), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Dether', 'DTH', 354829.52259999997), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('DaTa eXchange', 'DTX', 353778.4715492001), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Block Array', 'ARY', 352125.028500753), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('EncryptoTel [WAVES]', 'ETT', 351710.6648777421), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Worldcore', 'WRC', 348752.5608421144), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Pylon Network', 'PYLNT', 347078.1320046978), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Obsidian', 'ODN', 346681.86563972523), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Eristica', 'ERT', 346005.3367206352), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Shard', 'SHARD', 345693.1881355923), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Ties.DB', 'TIE', 343476.7511922684), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Voise', 'VOISE', 342194.4159203394), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('SportyCo', 'SPF', 334686.4331053793), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Paymon', 'PMNT', 330872.3025895552), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Equal', 'EQL', 320592.5046532164), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('SmartFox', 'FOX', 316362.5109363846), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Tokenbox', 'TBX', 315818.5519277076), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('KanadeCoin', 'KNDC', 308682.37238995), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Oyster Shell', 'SHL', 307692.990464335), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('LALA World', 'LALA', 303307.5870833645), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('EBCH', 'EBCH', 302392.26332175), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Arbidex', 'ABX', 290996.1616063656), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Universal Currency', 'UNIT', 290808.48958999995), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Blocktrade Token', 'BTT', 284257.9458810912), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Mainstream For The Underground', 'MFTU', 279584.844), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('FintruX Network', 'FTX', 275298.771), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Gladius Token', 'GLA', 269387.16141889984), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('NetKoin', 'NTK', 264124.97702437), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Crowdholding', 'YUP', 262363.53688532277), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Iungo', 'ING', 260794.5356945592), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('ATBCoin', 'ATB', 260158.06384656002), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Upfiring', 'UFR', 258535.079208), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('PRCoin', 'PRC', 256710.558), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('FidentiaX', 'FDX', 254609.32), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Peerguess', 'GUESS', 252273.9220079956), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('BitWhite', 'BTW', 251738.79155936438), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Evimeria', 'EVI', 246165.00072796797), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('BROTHER', 'BRAT', 242509.428), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('CryCash', 'CRC', 239708.3936195357), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Rupee', 'RUP', 238167.6479279702), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('LogisCoin', 'LGS', 238150.70698333738), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Omni', 'OMNI', 236323.9107960432), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Birake', 'BIR', 235715.31440435), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Transcodium', 'TNS', 231469.12470808259), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('CannabisCoin', 'CANN', 230891.12546880002), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('EXRNchain', 'EXRN', 230308.49999999997), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Chronologic', 'DAY', 229698.4804478708), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('nUSD', 'NUSD', 226192.9307604316), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Blue Protocol', 'BLUE', 222535.23538248538), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Tigereum', 'TIG', 222409.18959959492), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('DraftCoin', 'DFT', 220315.167), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('SIMDAQ', 'SMQ', 220185.847247506), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('WeTrust', 'TRST', 219887.10038925), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('BetterBetting', 'BETR', 217970.8323920568), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Knoxstertoken', 'FKX', 216516.877779456), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('BlockCAT', 'CAT', 216224.76465029301), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Fabric Token', 'FT', 215872.0891), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Lethean', 'LTHN', 211950.7868), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('BitRent', 'RNTB', 209835.971725), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('VULCANO', 'VULC', 206505.6240541634), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Live Stars', 'LIVE', 206208.621819416), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('X8X Token', 'X8X', 202997.4217536078), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Syndicate', 'SYNX', 196227.5063151546), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Ethereum Monero', 'EXMR', 195792.67955210147), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Invacio', 'INV', 194076.2965409268), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Truegame', 'TGAME', 190797.4884714248), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Sether', 'SETH', 189745.69005485703), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Tracto', 'TRCT', 189023.7515808987), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Elcoin', 'EL', 188422.5378161734), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Aigang', 'AIX', 185894.8632307296), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Phonecoin', 'PHON', 181946.72976), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Emphy', 'EPY', 180937.046734462), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Magnum', 'MGM', 180921.925), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Elite', '1337', 177643.966312965), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Xchange', 'XCG', 175732.9834283386), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Ethorse', 'HORSE', 175479.1016450676), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Bitradio', 'BRO', 170384.2928073252), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Unibright', 'UBT', 164558.44695587398), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('SagaCoin', 'SAGA', 164354.00919), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('PRiVCY', 'PRIV', 164189.63687455322), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('ACE (TokenStars)', 'ACE', 163264.3039068834), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Blockpool', 'BPL', 156602.284818574), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Soniq', 'SONIQ', 152380.154976942), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Tourist Token', 'TOTO', 151134.198154002), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('TEAM (TokenStars)', 'TEAM', 149758.0739858085), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Ethereum Gold', 'ETG', 149635.5324), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Kolion', 'KLN', 149496.2837264868), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Bitsum', 'BSM', 149037.9221994784), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('WELL', 'WELL', 148223.3838911787), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Local World Forwarders', 'LWF', 145168.2465121979), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('EUNO', 'EUNO', 145053.85921563962), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Octoin Coin', 'OCC', 144582.42919478042), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Bank Coin', 'BANK', 143951.68907368998), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('MicroMoney', 'AMM', 142622.2450911192), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('MagicCoin', 'MAGE', 141174.80025), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('DigitalPrice', 'DP', 141156.8603209122), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Rimbit', 'RBT', 140129.4415537852), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('BioCoin', 'BIO', 139723.5444190398), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Digix Gold Token', 'DGX', 137229.25987219), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Galactrum', 'ORE', 136952.355384), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Ourcoin', 'OUR', 135355.13622579898), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('PinkCoin', 'PINK', 134607.9856538084), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Asiadigicoin', 'ADCN', 133771.5910684038), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('View', 'VIEW', 132908.7049156164), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Sp8de', 'SPX', 132700.0488970284), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('CampusCoin', 'CMPCO', 132026.36), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Nullex', 'NLX', 131618.05880754022), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Hacken', 'HKN', 131456.66444152378), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Internet of People', 'IOP', 124108.1177086464), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Roofs', 'ROOFS', 123747.66300000002), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('WandX', 'WAND', 123545.12483827591), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('OP Coin', 'OPC', 121357.80955536051), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Startcoin', 'START', 120603.5280397695), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Universe', 'UNI', 113561.52752), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Coupecoin', 'COUPE', 112983.4157133618), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('ArbitrageCT', 'ARCT', 112537.6335486), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Tokia', 'TKA', 108844.5780542048), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Bela', 'BELA', 108709.9316402902), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('LiteCoin Ultra', 'LTCU', 108054.76575), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('CyberMusic', 'CYMT', 107956.1743413888), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Datarius Credit', 'DTRC', 106148.8140403292), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Atmos', 'ATMOS', 105263.664), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('e-Gulden', 'EFL', 103981.8808464335), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('MAZA', 'MAZA', 102155.72631571199), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('HUZU', 'HUZU', 101066.9849189196), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('eBitcoin', 'EBTC', 99137.7255186666), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('EtherSportz', 'ESZ', 97615.63116468), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('SunContract', 'SNC', 96486.5792350724), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Artex Coin', 'ATX', 93953.9), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('BitF', 'BITF', 93340.1890290408), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('EUNOMIA', 'ENTS', 90521.59999999999), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Jesus Coin', 'JC', 88573.941573186), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('The ChampCoin', 'TCC', 86644.5342723621), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Fox Trading', 'FOXT', 85908.563442), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Coimatic 3.0', 'CTIC3', 85348.1250885272), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('ChainCoin', 'CHC', 85330.87425871751), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Privatix', 'PRIX', 82735.71980779199), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('StarterCoin', 'STAC', 82661.55844), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('OPCoinX', 'OPCX', 81707.1162775936), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('EDRCoin', 'EDRC', 80283.9417920135), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Origami', 'ORI', 76697.3622022), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Stellite', 'XTL', 74646.684), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Etheriya', 'RIYA', 73466.231216), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Coin2.1', 'C2', 72378.11140226791), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('TOKYO', 'TOKC', 71870.2384645446), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Quebecoin', 'QBC', 71112.39495406), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Ethereum Dark', 'ETHD', 70029.5524205064), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Innova', 'INN', 68620.71157500001), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Havy', 'HAVY', 68164.8083842712), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('ZeusCrowdfunding', 'ZEUS', 67993.4476252618), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('DeltaChain', 'DELTA', 66652.7137688389), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Masternodecoin', 'MTNC', 66159.2114781978), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Gainer', 'GNR', 65897.6790643448), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('CarTaxi Token', 'CTX', 65823.224), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('LiteBitcoin', 'LBTC', 65018.0944836267), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Shadow Token', 'SHDW', 64457.3532), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('WITChain', 'WIT', 64158.7), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Pure', 'PUREX', 63869.911027344), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Blocklancer', 'LNC', 63451.258964793), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Skeincoin', 'SKC', 62981.473517015), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('KekCoin', 'KEK', 62663.7097), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Steneum Coin', 'STN', 62506.26354766641), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('FLiK', 'FLIK', 60182.873192919404), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Lobstex', 'LOBS', 60117.822835686005), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('VIVO', 'VIVO', 56949.991954000005), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('VapersCoin', 'VPRC', 56250.279), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('EquiTrader', 'EQT', 54184.65052), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('TrezarCoin', 'TZC', 52919.3592), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('XOVBank', 'XOV', 52799.3933458404), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('UCOM', 'UCOM', 52281.25173623201), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Safe Trade Coin', 'XSTC', 51345.56822538681), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('XDNA', 'XDNA', 49703.4965826), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Penguin Coin', 'PENG', 49474.0183352518), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Graphcoin', 'GRPH', 48982.368273657594), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Lightpaycoin', 'LPC', 48288.4943978808), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Deutsche eMark', 'DEM', 48061.261254748795), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Project-X', 'NANOX', 47656.0145424), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Apollon', 'XAP', 45696.971976611), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Starta', 'STA', 44921.1927487715), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Cazcoin', 'CAZ', 44285.873779359805), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Dollar Online', 'DOLLAR', 44238.3932280276), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Virtacoin', 'VTA', 44194.897773086), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('PluraCoin', 'PLURA', 43127.39), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Digiwage', 'WAGE', 43112.1144), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Wispr', 'WSP', 42626.7487990925), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('ConnectJob', 'CJT', 42456.7220397057), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Bitdeal', 'BDL', 42079.7626525437), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Qvolta', 'QVT', 41653.829008457), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Garlicoin', 'GRLC', 41408.691), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Archetypal Network', 'ACTP', 41137.0833239037), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Accelerator Network', 'ACC', 40755.692001825), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Bitcoin Adult', 'BTAD', 40638.028574915), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Network Token', 'NTWK', 40482.8150130252), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('XGOX', 'XGOX', 39200.616985774), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Altcoin', 'ALT', 39187.524434406405), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Intelligent Trading Foundation', 'ITT', 37571.7693325078), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('ICOS', 'ICOS', 36334.0502202232), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Crystal Clear ', 'CCT', 35910.3571212895), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Royal Kingdom Coin', 'RKC', 35623.52937), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('GeyserCoin', 'GSR', 35565.319010592), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Credence Coin', 'CRDNC', 35123.27286), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Neural Protocol', 'NRP', 34990.916965), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Regalcoin', 'REC', 34512.5231935516), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Bitblocks', 'BBK', 34336.00249873201), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('PKG Token', 'PKG', 34010.4745202055), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Bitcoin Token', 'BTK', 33846.696842528705), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('TokenDesk', 'TDS', 33489.321274692), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Nekonium', 'NUKO', 32878.566608121), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Trittium', 'TRTT', 32599.22345679), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Oceanlab', 'OCL', 31611.343050000003), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Vault Coin', 'VLTC', 31187.550000000003), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('ExchangeN', 'EXN', 30933.450589999997), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Forty Seven Bank', 'FSBT', 30246.831353640002), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('YoloCash', 'YLC', 29677.3685650728), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Bitvolt', 'VOLT', 29618.629247790002), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Bankcoin', 'B@', 29548.9958237375), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('CatoCoin', 'CATO', 29387.60137375), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Dinero', 'DIN', 29129.5207329174), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('INDINODE', 'XIND', 28895.732276892002), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('DROXNE', 'DRXNE', 28429.816611481703), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Trident Group', 'TRDT', 28229.885417526402), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Debitcoin', 'DBTC', 27368.5528), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Viuly', 'VIU', 27145.6003846368), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('HomeBlockCoin', 'HBC', 27145.1090937442), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Solaris', 'XLR', 26729.925505130403), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Dalecoin', 'DALC', 26077.4696189106), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('MyWish', 'WISH', 25667.3324251413), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Bionic', 'BNC0', 25485.2768884428), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('JobsCoin', 'JOBS', 24749.540498787002), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('NuShares', 'NSR', 23490.076049673004), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Suretly', 'SUR', 22396.137449212798), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Vsync', 'VSX', 22259.28529611), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('HOdlcoin', 'HODL', 21844.342352339998), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('PlayerCoin', 'PLACO', 21671.299000000003), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('BitAsean', 'BAS', 21050.537500000002), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('BitCoin One', 'BTCONE', 21018.8121), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('SCRIV NETWORK', 'SCRIV', 20655.449597611), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Kalkulus', 'KLKS', 20252.566609744), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('ZEST', 'ZEST', 19960.13782854), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Giant', 'GIC', 19895.06961), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('IrishCoin', 'IRL', 19539.567900000002), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Vivid Coin', 'VIVID', 19176.5084622111), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('EthBet', 'EBET', 18882.37781472), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('AmsterdamCoin', 'AMS', 18535.5765297837), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Ragnarok', 'RAGNA', 18202.149083274402), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('DigitalDevelopersFund', 'DDF', 17654.8717040625), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('GreenMed', 'GRMD', 17652.6898309494), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Eryllium', 'ERY', 16881.642369885), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Ignition', 'IC', 16837.533591431602), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Argus', 'ARGUS', 16704.048964320897), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('PAXEX', 'PAXEX', 16698.729346404), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Ryo Currency', 'RYO', 16658.2313721408), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('FantasyGold', 'FGC', 16216.2152709788), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('ELTCOIN', 'ELTCOIN', 15888.891), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Bettex Coin', 'BTXC', 15770.4561188096), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('AdultChain', 'XXX', 14838.5853693705), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Memetic / PepeCoin', 'MEME', 14727.1427413132), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('iBTC', 'IBTC', 14470.152682990602), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('AceD', 'ACED', 14249.8622541204), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# ...
# Row(('PIECoin', 'PIE', 0.0), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Solarflarecoin', 'SFC', 0.0), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('WhaleCoin', 'WHL', 0.0), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('GeertCoin', 'GEERT', 0.0), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Litecoin Plus', 'LCP', 0.0), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Actinium', 'ACM', 0.0), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('NoLimitCoin', 'NLC2', 0.0), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('CryptoPing', 'PING', 0.0), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Rhenium', 'XRH', 0.0), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Jin Coin', 'JIN', 0.0), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('FolmCoin', 'FLM', 0.0), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Carboncoin', 'CARBON', 0.0), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('BriaCoin', 'BRIA', 0.0), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('CryptoInsight', 'TKR', 0.0), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Breakout Stake', 'BRX', 0.0), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('UralsCoin', 'URALS', 0.0), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Bata', 'BTA', 0.0), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Cashcoin', 'CASH', 0.0), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('SHIELD', 'XSH', 0.0), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('BitBar', 'BTB', 0.0), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('StrongHands', 'SHND', -0.0775602366), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('HODL Bucks', 'HDLB', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Galaxy eSolutions', 'GES', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('HighCoin', 'HIGHT', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('NamoCoin', 'NAMO', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Centaure', 'CEN', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Electronic PK Chain', 'EPC', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Lendroid Support Token', 'LST', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Halloween Coin', 'HALLO', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('RabbitCoin', 'RBBT', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('EtherDelta Token', 'EDT', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Royalties', 'XRY', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('ValueChain', 'VLC', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('CryptCoin', 'CRYPT', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('BitSoar', 'BSR', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Arbitracoin', 'ATC', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('FAPcoin', 'FAP', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Excaliburcoin', 'EXC', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Saifu', 'SFU', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('ZSEcoin', 'ZSE', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('YouLive Coin', 'UC', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('EmberCoin', 'EMB', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Oxycoin', 'OXY', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Experience Token', 'EXT', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('MEX', 'MEX', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('GameChain System', 'GCS', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('DarexTravel', 'DART', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('EmaratCoin', 'AEC', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('SiaCashCoin', 'SCC', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Future1coin', 'F1C', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('TerraNova', 'TER', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('BlockCDN', 'BCDN', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Social Lending Token', 'SLT', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('CARAT', 'CARAT', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('QYNO', 'QNO', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('KingXChain', 'KXC', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Atheios', 'ATH', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Cropcoin', 'CROP', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Cryptrust', 'CTRT', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Ubcoin Market', 'UBC', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('SnipCoin', 'SNIP', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Trendercoin', 'TDC', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('BFFDoom', 'BFF', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Alttex', 'ALTX', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('XRT Token', 'XRT', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Obitan Chain', 'OBTC', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('BitCapitalVendor', 'BCV', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('StarCoin', 'KST', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Coin2Play', 'C2P', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Iridium', 'IRD', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('GIGA', 'XG', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Infinipay', 'IFP', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Carboneum [C8] Token', 'C8', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('CottonCoin', 'COTN', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Ether-1', 'ETHO', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Bodhi [ETH]', 'BOE', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('BitSerial', 'BTE', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Compound Coin', 'COMP', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('GazeCoin', 'GZE', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Thunderstake', 'TSC', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Labh Coin', 'LABH', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('CarBlock', 'CAR', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('SegWit2x', 'B2X', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Mallcoin', 'MLC', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('MarxCoin', 'MARX', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('MIRQ', 'MRQ', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('InternationalCryptoX', 'INCX', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Aegeus', 'AEG', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Gentarium', 'GTM', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('DWS', 'DWS', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('PlusOneCoin', 'PLUS1', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Rubex Money', 'RBMC', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('TWIST', 'TWIST', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Bitbase', 'BTBc', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('EncryptoTel [ETH]', 'ETT', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('MMOCoin', 'MMO', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Elliot Coin', 'ELLI', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('BTCMoon', 'BTCM', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Civitas', 'CIV', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('X12 Coin', 'X12', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Indicoin', 'INDI', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('SONO', 'SONO', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('PrimeStone', 'PSC', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('iDealCash', 'DEAL', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('iQuant', 'IQT', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Cyder', 'CYDER', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('CORION', 'COR', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Mero', 'MERO', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('NEO GOLD', 'NEOG', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Qurito', 'QURO', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Defense', 'DFS', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('JIYO', 'JIYOX', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Rentledger', 'RTL', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Crypto Improvement Fund', 'CIF', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Wink', 'WINK', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Adenz', 'DNZ', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('GOLD Reward Token', 'GRX', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('ARLIZE', 'ARLIZE', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Wi Coin', 'WIC', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Ferron', 'FRRN', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Puregold Token', 'PGT', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Master Contract Token', 'MCT', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Minex', 'MINEX', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Cyber Movie Chain', 'CMCT', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('InterCrone', 'ICR', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Olympic', 'OLMP', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Decentralized Asset Trading Platform', 'DATP', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('EscrowCoin', 'ESCO', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Concierge Coin', 'CCC', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('PitisCoin', 'PTS', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('FundToken', 'FUNDZ', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Sphre AIR ', 'XID', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('YUKI', 'YUKI', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('ERA', 'ERA', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('WeToken', 'WT', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('CMITCOIN', 'CMIT', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('SHPING', 'SHPING', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Eligma Token', 'ELI', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Cloud', 'CLD', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('SuperEdge', 'ECT', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('KWHCoin', 'KWH', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('wys Token', 'WYS', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Gemini Dollar', 'GUSD', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Bitnation', 'XPAT', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('GenesisX', 'XGS', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Superior Coin', 'SUP', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Pecunio', 'PCO', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Helper Search Token', 'HSN', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Graviocoin', 'GIO', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Bastonet', 'BSN', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Digital Asset Exchange Token', 'DAXT', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('First Bitcoin Capital', 'BITCF', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Globalvillage Ecosystem', 'GVE', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('SaveNode', 'SNO', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('empowr coin', 'EMPR', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Vestoria', 'VSTR', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('XTRD', 'XTRD', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Promotion Coin', 'PC', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('CARDbuyers', 'BCARD', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Level Up Coin', 'LUC', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Couchain', 'COU', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Hero', 'HERO', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Budbo', 'BUBO', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('ContractNet', 'CNET', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Esports Token', 'EST', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('SURETY', 'SURE', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Super Game Chain', 'SGCC', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('SecureCloudCoin', 'SC2', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('AWARE', 'AT', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Davinci Coin', 'DAC', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('SalPay', 'SAL', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('BitUP Token', 'BUT', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('PWR Coin', 'PWR', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Infinitecoin', 'IFC', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Cubits', 'QBT', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('GoldMaxCoin', 'GMX', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Sakuracoin', 'SKR', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Tattoocoin (Limited Edition)', 'TLE', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Bitok', 'BITOK', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Bubble', 'BUB', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Omicron', 'OMC', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Ethereum Lite', 'ELITE', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('EA Coin', 'EAG', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('DynamicCoin', 'DMC', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Francs', 'FRN', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Magnetcoin', 'MAGN', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('RichCoin', 'RICHX', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Akuya Coin', 'AKY', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Huncoin', 'HNC', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Themis', 'GET', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Pandemia', 'PNDM', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('Qube', 'QUBE', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('EJOY', 'EJOY', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})
# Row(('HOLD', 'HOLD', None), {'name': 0, 'symbol': 1, 'usd_avail_supply': 2})

# %%
# 4 -- 5 coins w/ greatest %age growth in last week

q = ('SELECT name, symbol, usd_pct_chg_7d FROM `coinmarketcap.20181017` WHERE usd_pct_chg_7d IS NOT NULL AND usd_pct_chg_7d > 0 ORDER BY usd_pct_chg_7d DESC LIMIT 5;')
query_job = bq.query(q)  # API request
rows = query_job.result()  # Waits for query to finish

for row in rows:
  print(row)
# Out:
# Row(('Cashcoin', 'CASH', 791.11), {'name': 0, 'symbol': 1, 'usd_pct_chg_7d': 2})
# Row(('TRONCLASSIC', 'TRXC', 570.34), {'name': 0, 'symbol': 1, 'usd_pct_chg_7d': 2})
# Row(('PitisCoin', 'PTS', 445.87), {'name': 0, 'symbol': 1, 'usd_pct_chg_7d': 2})
# Row(('SuperCoin', 'SUPER', 442.05), {'name': 0, 'symbol': 1, 'usd_pct_chg_7d': 2})
# Row(('FREE Coin', 'FREE', 435.57), {'name': 0, 'symbol': 1, 'usd_pct_chg_7d': 2})

# %%
# 5 -- how many tickers contain 'X'

q = ('SELECT symbol FROM `coinmarketcap.20181017` WHERE REGEXP_CONTAINS(symbol,"X");')
query_job = bq.query(q)  # API request
rows = query_job.result()  # Waits for query to finish

i = 0
for row in rows:
  i += 1
  
print('{} ticker symbols contain the letter "X"'.format(i))
# Out:
# 271 ticker symbols contain the letter "X"
